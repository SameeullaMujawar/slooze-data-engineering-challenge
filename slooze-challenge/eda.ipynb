# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("data/products.csv")
df.head()
# Out:
#     product_name    price          supplier location     category
# 0      iPhone 5s   199.99  Multiple Vendors   Global  smartphones
# 1       iPhone 6   299.99  Multiple Vendors   Global  smartphones
# 2  iPhone 13 Pro  1099.99  Multiple Vendors   Global  smartphones
# 3       iPhone X   899.99  Multiple Vendors   Global  smartphones
# 4       Oppo A57   249.99  Multiple Vendors   Global  smartphones

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_name  21 non-null     object
#  1   price         21 non-null     float64
#  2   supplier      21 non-null     object
#  3   location      21 non-null     object
#  4   category      21 non-null     object
# dtypes: float64(1), object(4)
# memory usage: 972.0+ bytes
#              price
# count    21.000000
# mean    695.228095
# std     567.429459
# min     149.990000
# 25%     299.990000
# 50%     399.990000
# 75%    1099.990000
# max    1999.990000

# %%
plt.figure(figsize=(6,4))
df['category'].value_counts().plot(kind='bar')
plt.title("Products by Category")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df['price'], bins=15)
plt.title("Price Distribution")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
df['product_name'].value_counts().head(10).plot(kind='barh')
plt.title("Top Products")
plt.show()

# %%
df.groupby('category')['price'].mean().plot(kind='bar')
plt.title("Average Price by Category")
plt.show()
